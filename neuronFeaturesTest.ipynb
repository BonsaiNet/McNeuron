# %%
import numpy as np
import McNeuron
import matplotlib.pyplot as plt
from copy import deepcopy
from numpy.linalg import inv
from collections import Counter
from random import randint
import pickle
# %matplotlib inline

# %%
neuron = McNeuron.Neuron("neuron.txt")

# %%
neuron.set_features('all')
# Out:
# /Users/anirudhnatarajan/Documents/UPenn/McNeuron/McNeuron/Neuron.py:953: RuntimeWarning: divide by zero encountered in double_scalars
#   t[i] = np.arctan(h/b)

# %%
neuron.features['Volume']
# Out:
# 8468.4003845373791

# %%
neuron.features['branching stems']
# Out:
# array([ 7.])

# %%
neuron.features['Tips']
# Out:
# 85

# %%
McNeuron.visualize.plot_2D(neuron)

# %%
McNeuron.visualize.plot_3D(neuron)

# %%
plt.hist(neuron.features['Elevation'],normed=True,alpha=0.5)
plt.hist(neuron.features['Tilt Local'],normed=True,alpha=0.5)
plt.hist(neuron.features['Amplitude Local'],normed=True,alpha=0.5)
# Out:
# (array([ 0.49912301,  0.12478075,  0.20796792,  0.49912301,  0.49912301,
#          0.41593584,  0.45752942,  0.12478075,  0.16637434,  0.2495615 ]),
#  array([  2.30434675e-03,   3.10537291e-01,   6.18770235e-01,
#           9.27003178e-01,   1.23523612e+00,   1.54346907e+00,
#           1.85170201e+00,   2.15993495e+00,   2.46816790e+00,
#           2.77640084e+00,   3.08463379e+00]),
#  <a list of 10 Patch objects>)
